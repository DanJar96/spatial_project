# %%
import pandas as pd

# %%
df = pd.read_csv('../gadm1_nuts3.tsv', sep='\t', header=0)

# %%
df
# Out:
#          user_loc fr_loc  scaled_sci
# 0             ABW    ABW    11264841
# 1             ABW   AGO1          38
# 2             ABW  AGO10          34
# 3             ABW  AGO11          32
# 4             ABW  AGO12          23
# ...           ...    ...         ...
# 63824116     ZWE9   ZWE5      305709
# 63824117     ZWE9   ZWE6      365478
# 63824118     ZWE9   ZWE7      715880
# 63824119     ZWE9   ZWE8      722214
# 63824120     ZWE9   ZWE9    15475362
#
# [63824121 rows x 3 columns]

# %%
df_finland = df[ (df['user_loc'].str.contains('FI')) &  (df['fr_loc'].str.contains('FI'))]

# %%
df_finland
# Out:
#          user_loc fr_loc  scaled_sci
# 12048920    FI193  FI193     2433320
# 12048921    FI193  FI194      194521
# 12048922    FI193  FI195       63308
# 12048923    FI193  FI196       82296
# 12048924    FI193  FI197      193217
# ...           ...    ...         ...
# 12192736    FI200  FI1D5       38534
# 12192737    FI200  FI1D7       12125
# 12192738    FI200  FI1D8        6068
# 12192739    FI200  FI1D9        8007
# 12192740    FI200  FI200    30174664
#
# [361 rows x 3 columns]

# %%
nuts_codes = pd.read_csv('../finland_nuts3.csv', sep=',')

# %%
nuts_codes
# Out:
#    nuts_code  nuts_level          country        nuts_1  \
# 0         FI         0.0  SUOMI / FINLAND           NaN
# 1        FI1         1.0              NaN  MANNER-SUOMI
# 2       FI19         2.0              NaN           NaN
# 3      FI193         3.0              NaN           NaN
# 4      FI194         3.0              NaN           NaN
# 5      FI195         3.0              NaN           NaN
# 6      FI196         3.0              NaN           NaN
# 7      FI197         3.0              NaN           NaN
# 8       FI1B         2.0              NaN           NaN
# 9      FI1B1         3.0              NaN           NaN
# 10      FI1C         2.0              NaN           NaN
# 11     FI1C1         3.0              NaN           NaN
# 12     FI1C2         3.0              NaN           NaN
# 13     FI1C3         3.0              NaN           NaN
# 14     FI1C4         3.0              NaN           NaN
# 15     FI1C5         3.0              NaN           NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mahdiazhari/spatial-data/spatial_project/scripts/sci_prep.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mahdiazhari/spatial-data/spatial_project/scripts/sci_prep.ipynb#ch0000007?line=0'>1</a> nuts_codes_fi = nuts_codes[ (nuts_codes['nuts_code'].str.contains('FI'))]
#
# File /opt/anaconda3/envs/spatialimages/lib/python3.8/site-packages/pandas/core/frame.py:3495, in DataFrame.__getitem__(self, key)
#    <a href='file:///opt/anaconda3/envs/spatialimages/lib/python3.8/site-packages/pandas/core/frame.py?line=3491'>3492</a>     return self.where(key)
#    <a href='file:///opt/anaconda3/envs/spatialimages/lib/python3.8/site-packages/pandas/core/frame.py?line=3493'>3494</a> # Do we have a (boolean) 1d indexer?
# ...
